# %% [markdown]
# # Exploring the trainbow hNILs

# %% [markdown]
# ## 1. Environment set up

# %% [markdown]
# Read in the required libraries

# %%
import sys
sys.path.append("../") # go to parent dir

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import trainbow.utils as utils
import trainbow.visualizations.image_viewers as viz
import trainbow.batch.segmenters as seg
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_18765/1706557331.py in <cell line: 7>()
#       5 import pandas as pd
#       6 import matplotlib.pyplot as plt
# ----> 7 import trainbow.utils as utils
#       8 import trainbow.visualizations.image_viewers as viz
#       9 import trainbow.batch.segmenters as seg
#
# ModuleNotFoundError: No module named 'trainbow'

# %% [markdown]
# Set up the experiment specific information

# %%
plate_id = 'PB2454' #plate id
microscope_id = 6 # techdev scope or nikon 4
#Fluroscent map
channel_map ={
    'DAPI':1,
    'eGFP':2,
    'mOrange':0,
    'mKate2':3,
    'DPC_top':4,
    'DPC_bottom':5,
    'DPC_left':6,
    'DPC_right':7
}

well_map = {
            "Mix" : ['A01','A02'],
            "Control" : ['A03','A04'],
    
            "CA137_0ng" : ['B01'],
            "CA137_250ng" : ['B02'],
            "CA137_500ng" : ['B03'],
            "CA137_1000ng" : ['B04'],
            
            "CM137_0ng" : ['C01'],
            "CM137_250ng" : ['C02'],
            "CM137_500ng" : ['C03'],
            "CM137_1000ng" : ['C04'],
            
}

bucket = 's3://insitro-user/'
output_dir = os.path.join('saradha/',plate_id)

experiment_acquisition = utils.database_utils.create_acquistion_df(plate_id,microscope_id)
#drop duplicate file paths - keeping only the last row
experiment_acquisition = experiment_acquisition.drop_duplicates(subset='file_path', keep="last")
# Out:
# For the plate id PB2454, 1 unique measurements were found
# Using 10 cpus
# 2022-09-02 19:26:28,891 [INFO] >>>> using CPU
# 2022-09-02 19:26:28,938 [INFO] >>>> using CPU
# 2022-09-02 19:26:28,973 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,045 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,151 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,233 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,262 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,442 [INFO] >>>> using CPU
# 2022-09-02 19:26:29,547 [INFO] >>>> using CPU
# 2022-09-02 19:26:30,144 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,161 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,132 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,281 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,300 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,427 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,466 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,472 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:30,896 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:26:31,252 [INFO] >>>> using CPU
# 2022-09-02 19:26:32,452 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:01,501 [INFO] >>>> using CPU
# 2022-09-02 19:27:01,684 [INFO] >>>> using CPU
# 2022-09-02 19:27:04,565 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:04,651 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:05,336 [INFO] >>>> using CPU
# 2022-09-02 19:27:06,171 [INFO] >>>> using CPU
# 2022-09-02 19:27:08,030 [INFO] >>>> using CPU
# 2022-09-02 19:27:08,620 [INFO] >>>> using CPU
# 2022-09-02 19:27:09,150 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:09,824 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:10,186 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:11,024 [INFO] ~~~ FINDING MASKS ~~~
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# 2022-09-02 19:27:21,895 [INFO] >>>> using CPU
# 2022-09-02 19:27:22,948 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:26,996 [INFO] >>>> using CPU
# 2022-09-02 19:27:29,748 [INFO] >>>> using CPU
# 2022-09-02 19:27:30,508 [INFO] >>>> using CPU
# 2022-09-02 19:27:31,240 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:32,182 [INFO] >>>> using CPU
# 2022-09-02 19:27:33,167 [INFO] >>>> using CPU
# 2022-09-02 19:27:34,184 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:34,377 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:38,017 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:39,048 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:40,800 [INFO] >>>> using CPU
# 2022-09-02 19:27:41,957 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:44,772 [INFO] >>>> using CPU
# 2022-09-02 19:27:45,897 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:53,274 [INFO] >>>> using CPU
# 2022-09-02 19:27:55,695 [INFO] >>>> using CPU
# 2022-09-02 19:27:55,860 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:59,391 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:27:59,369 [INFO] >>>> using CPU
# 2022-09-02 19:27:59,432 [INFO] >>>> using CPU
# 2022-09-02 19:28:00,307 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:28:00,385 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:01,813 [INFO] >>>> using CPU
# 2022-09-02 19:29:01,850 [INFO] >>>> using CPU
# 2022-09-02 19:29:02,633 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:02,658 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:13,600 [INFO] >>>> using CPU
# 2022-09-02 19:29:13,940 [INFO] >>>> using CPU
# 2022-09-02 19:29:14,237 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:14,361 [INFO] >>>> using CPU
# 2022-09-02 19:29:14,499 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:17,949 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:23,272 [INFO] >>>> using CPU
# 2022-09-02 19:29:24,448 [INFO] >>>> using CPU
# 2022-09-02 19:29:25,079 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:25,663 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:29:46,784 [INFO] >>>> using CPU
# 2022-09-02 19:29:47,325 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:04,420 [INFO] >>>> using CPU
# 2022-09-02 19:30:04,903 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:04,995 [INFO] >>>> using CPU
# 2022-09-02 19:30:05,019 [INFO] >>>> using CPU
# 2022-09-02 19:30:05,533 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:05,535 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:23,098 [INFO] >>>> using CPU
# 2022-09-02 19:30:25,057 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:45,247 [INFO] >>>> using CPU
# 2022-09-02 19:30:45,337 [INFO] >>>> using CPU
# 2022-09-02 19:30:45,814 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:30:45,888 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:31:06,605 [INFO] >>>> using CPU
# 2022-09-02 19:31:08,570 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:31:58,498 [INFO] >>>> using CPU
# 2022-09-02 19:32:00,228 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:32:02,398 [INFO] >>>> TOTAL TIME 279.45 sec
# 2022-09-02 19:32:04,906 [INFO] >>>> TOTAL TIME 273.67 sec
# 2022-09-02 19:32:09,409 [INFO] >>>> using CPU
# 2022-09-02 19:32:09,880 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:32:11,290 [INFO] >>>> using CPU
# 2022-09-02 19:32:11,827 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:32:16,806 [INFO] >>>> TOTAL TIME 260.95 sec
# 2022-09-02 19:32:24,164 [INFO] >>>> using CPU
# 2022-09-02 19:32:24,587 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:32:30,587 [INFO] >>>> TOTAL TIME 196.35 sec
# 2022-09-02 19:32:37,909 [INFO] >>>> using CPU
# 2022-09-02 19:32:38,473 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:32:39,990 [INFO] >>>> TOTAL TIME 194.91 sec
# 2022-09-02 19:32:48,042 [INFO] >>>> using CPU
# 2022-09-02 19:32:48,618 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:33:10,423 [INFO] >>>> TOTAL TIME 184.89 sec
# 2022-09-02 19:33:17,846 [INFO] >>>> using CPU
# 2022-09-02 19:33:18,442 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:33:50,721 [INFO] >>>> TOTAL TIME 184.91 sec
# 2022-09-02 19:33:55,040 [INFO] >>>> TOTAL TIME 189.15 sec
# 2022-09-02 19:33:56,970 [INFO] >>>> using CPU
# 2022-09-02 19:33:57,359 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:34:02,440 [INFO] >>>> using CPU
# 2022-09-02 19:34:02,874 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:34:09,049 [INFO] >>>> TOTAL TIME 180.48 sec
# 2022-09-02 19:34:16,265 [INFO] >>>> using CPU
# 2022-09-02 19:34:16,735 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:35:03,150 [INFO] >>>> TOTAL TIME 171.32 sec
# 2022-09-02 19:35:04,082 [INFO] >>>> TOTAL TIME 174.20 sec
# 2022-09-02 19:35:04,537 [INFO] >>>> TOTAL TIME 184.31 sec
# 2022-09-02 19:35:09,427 [INFO] >>>> using CPU
# 2022-09-02 19:35:09,823 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:35:10,719 [INFO] >>>> using CPU
# 2022-09-02 19:35:10,999 [INFO] >>>> using CPU
# 2022-09-02 19:35:11,101 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:35:11,348 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:35:15,184 [INFO] >>>> TOTAL TIME 170.60 sec
# 2022-09-02 19:35:21,948 [INFO] >>>> using CPU
# 2022-09-02 19:35:22,400 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:35:46,247 [INFO] >>>> TOTAL TIME 177.63 sec
# 2022-09-02 19:35:53,806 [INFO] >>>> using CPU
# 2022-09-02 19:35:54,244 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:36:10,193 [INFO] >>>> TOTAL TIME 171.75 sec
# 2022-09-02 19:36:17,238 [INFO] >>>> using CPU
# 2022-09-02 19:36:17,632 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:36:43,102 [INFO] >>>> TOTAL TIME 160.23 sec
# 2022-09-02 19:36:49,175 [INFO] >>>> TOTAL TIME 171.82 sec
# 2022-09-02 19:36:49,912 [INFO] >>>> using CPU
# 2022-09-02 19:36:50,423 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:36:56,432 [INFO] >>>> using CPU
# 2022-09-02 19:36:56,852 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:37:02,919 [INFO] >>>> TOTAL TIME 166.18 sec
# 2022-09-02 19:37:09,599 [INFO] >>>> using CPU
# 2022-09-02 19:37:10,007 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:38:01,232 [INFO] >>>> TOTAL TIME 171.41 sec
# 2022-09-02 19:38:01,700 [INFO] >>>> TOTAL TIME 170.60 sec
# 2022-09-02 19:38:06,547 [INFO] >>>> TOTAL TIME 175.20 sec
# 2022-09-02 19:38:10,248 [INFO] >>>> TOTAL TIME 167.85 sec
# 2022-09-02 19:38:12,240 [INFO] >>>> using CPU
# 2022-09-02 19:38:12,364 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 19:38:32,661 [INFO] >>>> TOTAL TIME 158.42 sec
# 2022-09-02 19:38:45,097 [INFO] >>>> TOTAL TIME 147.47 sec
# 2022-09-02 19:38:58,020 [INFO] >>>> TOTAL TIME 127.60 sec
# 2022-09-02 19:39:02,308 [INFO] >>>> TOTAL TIME 125.46 sec
# 2022-09-02 19:39:04,415 [INFO] >>>> TOTAL TIME 114.41 sec
# 2022-09-02 19:39:10,859 [INFO] >>>> TOTAL TIME 58.49 sec

# %%
plate_id = 'PB2455' #plate id
microscope_id = 6 # techdev scope or nikon 4
#Fluroscent map
channel_map ={
    'DAPI':1,
    'eGFP':2,
    'mOrange':0,
    'mKate2':3,
    'DPC_top':4,
    'DPC_bottom':5,
    'DPC_left':6,
    'DPC_right':7
}

well_map = {
            "CD118_0ng" : ['A01'],
            "CD118_250ng" : ['A02'],
            "CD118_500ng" : ['A03'],
            "CD118_1000ng" : ['A04'],
            
            "CM130_0ng" : ['B01'],
            "CM130_250ng" : ['B02'],
            "CM130_500ng" : ['B03'],
            "CM130_1000ng" : ['B04'],
    
            "Cre-TAT" : ['C01'],
            "Mix" : ['C02','C03','C04'],
    
            
}

bucket = 's3://insitro-user/'
output_dir = os.path.join('saradha/',plate_id)

experiment_acquisition_p2 = utils.database_utils.create_acquistion_df(plate_id,microscope_id)
#drop duplicate file paths - keeping only the last row
experiment_acquisition_p2 = experiment_acquisition_p2.drop_duplicates(subset='file_path', keep="last")

## instance segmentation 
subset_df_p2 = experiment_acquisition_p2.groupby('well_loc').apply(lambda x: x.sample(10)).reset_index(drop=True)

nuc_mask_paths = seg.segment_nuclei_batch(acquisition_df = subset_df_p2,
                                          channel_map = channel_map,
                                          num_cpus = 10,
                                          output_dir = os.path.join(bucket,output_dir)
                                          )
cell_mask_paths = seg.segment_cells_from_nuclei_batch(acquisition_df = subset_df_p2,
                                                      channel_map = channel_map,
                                                      num_cpus = 10,
                                                      output_dir = os.path.join(bucket,output_dir))

#save the features df
image_features = extract_features_batch_FOV(acquisition_df = experiment_acquisition,
                                      channel_map = channel_map,
                                      num_cpus = 10,
                                      output_dir = os.path.join(bucket,output_dir))
utils.database_utils.save_object(image_features,os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))
img_features_plate2 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))

# %%
features_plate1 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))
