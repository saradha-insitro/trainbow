# %% [markdown]
# # Exploring the trainbow hNILs

# %% [markdown]
# ## 1. Environment set up

# %% [markdown]
# Read in the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import trainbow.utils as utils
import trainbow.visualizations.image_viewers as viz
import trainbow.batch.segmenters as seg
import os
# Out:
# 2022-09-02 14:44:10,291 [INFO] WRITING LOG OUTPUT TO /home/ec2-user/.cellpose/run.log

# %% [markdown]
# Set up the experiment specific information

# %%
plate_id = 'PB2454' #plate id
microscope_id = 6 # techdev scope or nikon 4
#Fluroscent map
channel_map ={
    'DAPI':1,
    'eGFP':2,
    'mOrange':0,
    'mKate2':3,
    'DPC_top':4,
    'DPC_bottom':5,
    'DPC_left':6,
    'DPC_right':7
}

well_map = {
            "Mix" : ['A01','A02'],
            "Control" : ['A03','A04'],
    
            "CA137_0ng" : ['B01'],
            "CA137_250ng" : ['B02'],
            "CA137_500ng" : ['B03'],
            "CA137_1000ng" : ['B04'],
            
            "CM137_0ng" : ['C01'],
            "CM137_250ng" : ['C02'],
            "CM137_500ng" : ['C03'],
            "CM137_1000ng" : ['C04'],
            
}

bucket = 's3://insitro-user/'
output_dir = os.path.join('saradha/',plate_id)

experiment_acquisition = utils.database_utils.create_acquistion_df(plate_id,microscope_id)
#drop duplicate file paths - keeping only the last row
experiment_acquisition = experiment_acquisition.drop_duplicates(subset='file_path', keep="last")

## instance segmentation 
nuc_mask_paths = seg.segment_nuclei_batch(acquisition_df = experiment_acquisition,
                                          channel_map = channel_map,
                                          num_cpus = 10,
                                          output_dir = os.path.join(bucket,output_dir)
                                          )
cell_mask_paths = seg.segment_cells_from_nuclei_batch(acquisition_df = experiment_acquisition,
                                                      channel_map = channel_map,
                                                      num_cpus = 10,
                                                      output_dir = os.path.join(bucket,output_dir))

feat_paths = extract_features_batch(acquisition_df = experiment_acquisition,
                                  channel_map = channel_map,
                                  num_cpus = 10,
                                  output_dir = os.path.join(bucket,output_dir))

#save the features df
features = pd.concat([utils.database_utils.load_obj(os.path.join(bucket,path)) 
              for path in utils.database_utils.get_file_list(os.path.join(output_dir,"brainbow_features"))])

utils.database_utils.save_object(features,os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))
cell_features_plate1 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))

image_features = extract_features_batch_FOV(acquisition_df = experiment_acquisition,
                                      channel_map = channel_map,
                                      num_cpus = 10,
                                      output_dir = os.path.join(bucket,output_dir))
utils.database_utils.save_object(image_features,os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))
img_features_plate1 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))
# Out:
# For the plate id PB2454, 1 unique measurements were found
# Using 10 cpus
# 2022-09-02 14:44:17,257 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,365 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,370 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,399 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,424 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,506 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,519 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,535 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,539 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,585 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,600 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,628 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,639 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,699 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,719 [INFO] >>>> using CPU
# 2022-09-02 14:44:17,728 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,769 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,886 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:44:17,957 [INFO] >>>> using CPU
# 2022-09-02 14:44:18,250 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:17,891 [INFO] >>>> TOTAL TIME 180.47 sec
# 2022-09-02 14:47:18,267 [INFO] >>>> TOTAL TIME 180.68 sec
# 2022-09-02 14:47:19,024 [INFO] >>>> TOTAL TIME 181.52 sec
# 2022-09-02 14:47:19,458 [INFO] >>>> TOTAL TIME 181.82 sec
# 2022-09-02 14:47:19,459 [INFO] >>>> TOTAL TIME 181.86 sec
# 2022-09-02 14:47:19,993 [INFO] >>>> TOTAL TIME 182.26 sec
# 2022-09-02 14:47:20,375 [INFO] >>>> TOTAL TIME 182.12 sec
# 2022-09-02 14:47:20,906 [INFO] >>>> TOTAL TIME 183.02 sec
# 2022-09-02 14:47:21,598 [INFO] >>>> TOTAL TIME 184.23 sec
# 2022-09-02 14:47:22,019 [INFO] >>>> TOTAL TIME 184.25 sec
# 2022-09-02 14:47:22,560 [INFO] >>>> using CPU
# 2022-09-02 14:47:22,569 [INFO] >>>> using CPU
# 2022-09-02 14:47:22,613 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:22,625 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:23,151 [INFO] >>>> using CPU
# 2022-09-02 14:47:23,251 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:23,700 [INFO] >>>> using CPU
# 2022-09-02 14:47:23,864 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:24,274 [INFO] >>>> using CPU
# 2022-09-02 14:47:24,448 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:24,804 [INFO] >>>> using CPU
# 2022-09-02 14:47:25,068 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:25,441 [INFO] >>>> using CPU
# 2022-09-02 14:47:25,652 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:26,277 [INFO] >>>> using CPU
# 2022-09-02 14:47:26,567 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:26,877 [INFO] >>>> using CPU
# 2022-09-02 14:47:27,254 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:47:27,313 [INFO] >>>> using CPU
# 2022-09-02 14:47:27,715 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:33,418 [INFO] >>>> using CPU
# 2022-09-02 14:49:35,895 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:36,102 [INFO] >>>> using CPU
# 2022-09-02 14:49:36,414 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:36,654 [INFO] >>>> using CPU
# 2022-09-02 14:49:37,086 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:41,200 [INFO] >>>> using CPU
# 2022-09-02 14:49:41,648 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:42,200 [INFO] >>>> using CPU
# 2022-09-02 14:49:42,669 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:54,441 [INFO] >>>> using CPU
# 2022-09-02 14:49:54,428 [INFO] >>>> using CPU
# 2022-09-02 14:49:54,650 [INFO] >>>> using CPU
# 2022-09-02 14:49:54,749 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:54,759 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:49:54,982 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:01,457 [INFO] >>>> using CPU
# 2022-09-02 14:50:01,939 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:21,345 [INFO] >>>> using CPU
# 2022-09-02 14:50:21,430 [INFO] >>>> using CPU
# 2022-09-02 14:50:21,664 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:22,354 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:30,593 [INFO] >>>> using CPU
# 2022-09-02 14:50:31,026 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:51,767 [INFO] >>>> using CPU
# 2022-09-02 14:50:52,072 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:52,182 [INFO] >>>> using CPU
# 2022-09-02 14:50:52,479 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:50:56,055 [INFO] >>>> TOTAL TIME 212.19 sec
# 2022-09-02 14:50:56,201 [INFO] >>>> TOTAL TIME 213.58 sec
# 2022-09-02 14:51:02,052 [INFO] >>>> using CPU
# 2022-09-02 14:51:02,439 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:51:03,758 [INFO] >>>> using CPU
# 2022-09-02 14:51:04,086 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:51:32,443 [INFO] >>>> using CPU
# 2022-09-02 14:51:32,709 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:53:16,566 [INFO] >>>> TOTAL TIME 220.67 sec
# 2022-09-02 14:53:20,335 [INFO] >>>> TOTAL TIME 223.92 sec
# 2022-09-02 14:53:20,522 [INFO] >>>> TOTAL TIME 223.44 sec
# 2022-09-02 14:53:21,801 [INFO] >>>> using CPU
# 2022-09-02 14:53:22,036 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:53:26,762 [INFO] >>>> using CPU
# 2022-09-02 14:53:26,922 [INFO] >>>> using CPU
# 2022-09-02 14:53:27,152 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:53:27,372 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:53:45,112 [INFO] >>>> TOTAL TIME 230.35 sec
# 2022-09-02 14:53:47,096 [INFO] >>>> TOTAL TIME 225.16 sec
# 2022-09-02 14:53:50,630 [INFO] >>>> using CPU
# 2022-09-02 14:53:51,015 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:53:53,818 [INFO] >>>> using CPU
# 2022-09-02 14:53:54,280 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:03,857 [INFO] >>>> TOTAL TIME 212.83 sec
# 2022-09-02 14:54:10,285 [INFO] >>>> using CPU
# 2022-09-02 14:54:10,770 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:17,296 [INFO] >>>> TOTAL TIME 205.22 sec
# 2022-09-02 14:54:23,083 [INFO] >>>> using CPU
# 2022-09-02 14:54:23,549 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:28,439 [INFO] >>>> TOTAL TIME 205.99 sec
# 2022-09-02 14:54:29,500 [INFO] >>>> TOTAL TIME 205.41 sec
# 2022-09-02 14:54:36,426 [INFO] >>>> using CPU
# 2022-09-02 14:54:36,778 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:37,421 [INFO] >>>> using CPU
# 2022-09-02 14:54:37,804 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:40,758 [INFO] >>>> using CPU
# 2022-09-02 14:54:41,310 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:54:48,457 [INFO] >>>> TOTAL TIME 195.75 sec
# 2022-09-02 14:54:54,539 [INFO] >>>> using CPU
# 2022-09-02 14:54:55,020 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:01,650 [INFO] >>>> using CPU
# 2022-09-02 14:56:02,162 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:16,663 [INFO] >>>> TOTAL TIME 174.63 sec
# 2022-09-02 14:56:22,086 [INFO] >>>> using CPU
# 2022-09-02 14:56:22,483 [INFO] >>>> TOTAL TIME 175.33 sec
# 2022-09-02 14:56:22,532 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:28,225 [INFO] >>>> using CPU
# 2022-09-02 14:56:28,683 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:30,774 [INFO] >>>> TOTAL TIME 183.40 sec
# 2022-09-02 14:56:36,966 [INFO] >>>> using CPU
# 2022-09-02 14:56:37,514 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:47,959 [INFO] >>>> TOTAL TIME 176.94 sec
# 2022-09-02 14:56:53,201 [INFO] >>>> using CPU
# 2022-09-02 14:56:53,609 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:56:58,287 [INFO] >>>> TOTAL TIME 184.01 sec
# 2022-09-02 14:57:03,869 [INFO] >>>> using CPU
# 2022-09-02 14:57:04,251 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:57:10,761 [INFO] >>>> TOTAL TIME 179.99 sec
# 2022-09-02 14:57:17,602 [INFO] >>>> using CPU
# 2022-09-02 14:57:17,965 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:57:31,849 [INFO] >>>> TOTAL TIME 175.07 sec
# 2022-09-02 14:57:36,980 [INFO] >>>> TOTAL TIME 179.18 sec
# 2022-09-02 14:57:37,747 [INFO] >>>> using CPU
# 2022-09-02 14:57:38,158 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:57:42,979 [INFO] >>>> using CPU
# 2022-09-02 14:57:43,461 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:57:49,275 [INFO] >>>> TOTAL TIME 174.26 sec
# 2022-09-02 14:57:55,618 [INFO] >>>> using CPU
# 2022-09-02 14:57:56,177 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:58:24,021 [INFO] >>>> using CPU
# 2022-09-02 14:58:24,542 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:59:39,076 [INFO] >>>> TOTAL TIME 196.54 sec
# 2022-09-02 14:59:44,110 [INFO] >>>> using CPU
# 2022-09-02 14:59:44,531 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:59:45,474 [INFO] >>>> TOTAL TIME 196.79 sec
# 2022-09-02 14:59:51,211 [INFO] >>>> using CPU
# 2022-09-02 14:59:51,765 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 14:59:55,055 [INFO] >>>> TOTAL TIME 197.54 sec
# 2022-09-02 15:00:01,279 [INFO] >>>> using CPU
# 2022-09-02 15:00:01,783 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:00:08,160 [INFO] >>>> TOTAL TIME 194.55 sec
# 2022-09-02 15:00:13,684 [INFO] >>>> using CPU
# 2022-09-02 15:00:14,105 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:00:16,287 [INFO] >>>> TOTAL TIME 192.04 sec
# 2022-09-02 15:00:22,733 [INFO] >>>> using CPU
# 2022-09-02 15:00:23,176 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:00:35,130 [INFO] >>>> TOTAL TIME 197.17 sec
# 2022-09-02 15:00:41,739 [INFO] >>>> using CPU
# 2022-09-02 15:00:42,101 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:00:54,032 [INFO] >>>> TOTAL TIME 195.87 sec
# 2022-09-02 15:01:00,122 [INFO] >>>> using CPU
# 2022-09-02 15:01:00,477 [INFO] >>>> TOTAL TIME 197.02 sec
# 2022-09-02 15:01:00,517 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:01:07,130 [INFO] >>>> using CPU
# 2022-09-02 15:01:07,526 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:01:10,117 [INFO] >>>> TOTAL TIME 193.94 sec
# 2022-09-02 15:01:17,422 [INFO] >>>> using CPU
# 2022-09-02 15:01:17,900 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:01:27,990 [INFO] >>>> TOTAL TIME 183.45 sec
# 2022-09-02 15:01:34,891 [INFO] >>>> using CPU
# 2022-09-02 15:01:35,254 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:02:33,537 [INFO] >>>> TOTAL TIME 169.01 sec
# 2022-09-02 15:02:40,145 [INFO] >>>> using CPU
# 2022-09-02 15:02:40,597 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:02:46,230 [INFO] >>>> TOTAL TIME 174.46 sec
# 2022-09-02 15:02:52,417 [INFO] >>>> using CPU
# 2022-09-02 15:02:52,840 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:02:53,120 [INFO] >>>> TOTAL TIME 171.34 sec
# 2022-09-02 15:02:59,426 [INFO] >>>> using CPU
# 2022-09-02 15:02:59,906 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:03:05,492 [INFO] >>>> TOTAL TIME 171.39 sec
# 2022-09-02 15:03:12,045 [INFO] >>>> using CPU
# 2022-09-02 15:03:12,442 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:03:14,993 [INFO] >>>> TOTAL TIME 171.84 sec
# 2022-09-02 15:03:21,425 [INFO] >>>> using CPU
# 2022-09-02 15:03:21,838 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:03:30,440 [INFO] >>>> TOTAL TIME 168.34 sec
# 2022-09-02 15:03:37,023 [INFO] >>>> using CPU
# 2022-09-02 15:03:37,417 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:03:57,920 [INFO] >>>> TOTAL TIME 177.40 sec
# 2022-09-02 15:03:59,799 [INFO] >>>> TOTAL TIME 172.27 sec
# 2022-09-02 15:04:03,932 [INFO] >>>> using CPU
# 2022-09-02 15:04:04,199 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:04:06,216 [INFO] >>>> using CPU
# 2022-09-02 15:04:06,630 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:04:10,416 [INFO] >>>> TOTAL TIME 172.52 sec
# 2022-09-02 15:04:17,010 [INFO] >>>> using CPU
# 2022-09-02 15:04:17,398 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:04:28,808 [INFO] >>>> TOTAL TIME 173.55 sec
# 2022-09-02 15:04:34,898 [INFO] >>>> using CPU
# 2022-09-02 15:04:35,398 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:05:37,789 [INFO] >>>> TOTAL TIME 177.19 sec
# 2022-09-02 15:05:44,049 [INFO] >>>> using CPU
# 2022-09-02 15:05:44,430 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:06:00,636 [INFO] >>>> TOTAL TIME 187.80 sec
# 2022-09-02 15:06:03,012 [INFO] >>>> TOTAL TIME 183.11 sec
# 2022-09-02 15:06:07,287 [INFO] >>>> using CPU
# 2022-09-02 15:06:07,817 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:06:09,668 [INFO] >>>> using CPU
# 2022-09-02 15:06:10,138 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:06:11,924 [INFO] >>>> TOTAL TIME 179.48 sec
# 2022-09-02 15:06:18,585 [INFO] >>>> using CPU
# 2022-09-02 15:06:19,045 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:06:25,933 [INFO] >>>> TOTAL TIME 184.10 sec
# 2022-09-02 15:06:32,457 [INFO] >>>> using CPU
# 2022-09-02 15:06:32,858 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:06:33,464 [INFO] >>>> TOTAL TIME 176.05 sec
# 2022-09-02 15:06:40,068 [INFO] >>>> using CPU
# 2022-09-02 15:06:40,550 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:07:07,051 [INFO] >>>> TOTAL TIME 180.42 sec
# 2022-09-02 15:07:07,175 [INFO] >>>> TOTAL TIME 182.98 sec
# 2022-09-02 15:07:12,466 [INFO] >>>> using CPU
# 2022-09-02 15:07:12,742 [INFO] >>>> using CPU
# 2022-09-02 15:07:12,958 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:07:13,166 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:07:23,299 [INFO] >>>> TOTAL TIME 185.90 sec
# 2022-09-02 15:07:29,327 [INFO] >>>> using CPU
# 2022-09-02 15:07:29,916 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:07:35,093 [INFO] >>>> TOTAL TIME 179.69 sec
# 2022-09-02 15:07:42,320 [INFO] >>>> using CPU
# 2022-09-02 15:07:42,802 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:08:40,345 [INFO] >>>> TOTAL TIME 175.91 sec
# 2022-09-02 15:09:01,706 [INFO] >>>> TOTAL TIME 171.57 sec
# 2022-09-02 15:09:04,515 [INFO] >>>> TOTAL TIME 176.70 sec
# 2022-09-02 15:09:15,469 [INFO] >>>> TOTAL TIME 176.42 sec
# 2022-09-02 15:09:19,360 [INFO] >>>> TOTAL TIME 166.50 sec
# 2022-09-02 15:09:23,497 [INFO] >>>> TOTAL TIME 162.95 sec
# 2022-09-02 15:09:36,391 [INFO] >>>> TOTAL TIME 143.43 sec
# 2022-09-02 15:09:37,007 [INFO] >>>> TOTAL TIME 143.84 sec
# 2022-09-02 15:09:41,252 [INFO] >>>> using CPU
# 2022-09-02 15:09:41,435 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:09:42,152 [INFO] >>>> using CPU
# 2022-09-02 15:09:42,287 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:09:43,899 [INFO] >>>> TOTAL TIME 133.98 sec
# 2022-09-02 15:09:47,689 [INFO] >>>> TOTAL TIME 124.89 sec
# 2022-09-02 15:09:52,929 [INFO] >>>> using CPU
# 2022-09-02 15:09:53,131 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:10:35,161 [INFO] >>>> TOTAL TIME 53.73 sec
# 2022-09-02 15:10:38,872 [INFO] >>>> TOTAL TIME 56.58 sec
# 2022-09-02 15:10:42,713 [INFO] >>>> TOTAL TIME 49.58 sec
# 2022-09-02 15:10:46,960 [INFO] >>>> using CPU
# 2022-09-02 15:10:47,012 [INFO] ~~~ FINDING MASKS ~~~
# 2022-09-02 15:11:05,688 [INFO] >>>> TOTAL TIME 18.68 sec
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/ec2-user/insitro/trainbow/trainbow/batch/segmenters.py", line 30, in segment_nuclei
#     nuc_mask = seg.segment_nuclei_cellpose([processed_nuc])[0] #obtain nuc labelled image
#   File "/home/ec2-user/insitro/trainbow/trainbow/segmentation/cell_segmentation.py", line 31, in segment_nuclei_cellpose
#     nuc_masks, _, _, _ = model.eval(images,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py", line 257, in eval
#     masks, flows, styles = self.cp.eval(x,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py", line 471, in eval
#     maski, stylei, flowi = self.eval(x[i],
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py", line 515, in eval
#     masks, styles, dP, cellprob, p = self._run_cp(x,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py", line 572, in _run_cp
#     yf, style = self._run_nets(img, net_avg=net_avg,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py", line 397, in _run_nets
#     y0, style = self._run_net(img, augment=augment, tile=tile,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py", line 469, in _run_net
#     y, style = self._run_tiled(imgs, augment=augment, bsize=bsize,
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py", line 572, in _run_tiled
#     y0, style = self.network(IMG[irange], return_conv=return_conv)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py", line 341, in network
#     y, style = self.net(X)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py", line 199, in forward
#     T0 = self.upsample(style, T0, self.mkldnn)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py", line 166, in forward
#     x = self.up[n](x, xd[n], style, mkldnn=mkldnn)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py", line 117, in forward
#     x = self.proj(x) + self.conv[1](style, self.conv[0](x) + y, mkldnn=mkldnn)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/container.py", line 141, in forward
#     input = module(input)
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/utils/mkldnn.py", line 171, in forward
#     @torch.jit.script_method
#     def forward(self, x):
#         return torch.batch_norm(
#                ~~~~~~~~~~~~~~~~ <--- HERE
#             x,
#             self.weight,
# RuntimeError: [enforce fail at CPUAllocator.cpp:68] . DefaultCPUAllocator: can't allocate memory: you tried to allocate 102760448 bytes. Error code 12 (Cannot allocate memory)
#
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1976/339281809.py in <cell line: 41>()
#      39 subset_df = experiment_acquisition.groupby('well_loc').apply(lambda x: x.sample(10)).reset_index(drop=True)
#      40
# ---> 41 nuc_mask_paths = seg.segment_nuclei_batch(acquisition_df = subset_df,
#      42                                           channel_map = channel_map,
#      43                                           num_cpus = 10,
#
# ~/insitro/trainbow/trainbow/batch/segmenters.py in segment_nuclei_batch(acquisition_df, channel_map, num_cpus, output_dir)
#      80     input_output_paths= np.column_stack([file_paths,output_seg_imag_paths])
#      81     pool = mp.Pool(num_cpus)
# ---> 82     nuc_mask_dir = pool.map(segment_nuclei, [paths for paths in input_output_paths])
#      83
#      84     return nuc_mask_dir
#
# ~/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# ~/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py in worker()
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/miniconda3/envs/insitro/lib/python3.9/multiprocessing/pool.py in mapstar()
#      46
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#      49
#      50 def starmapstar(args):
#
# ~/insitro/trainbow/trainbow/batch/segmenters.py in segment_nuclei()
#      28     image = database_utils.read_image(input_image_path)
#      29     processed_nuc = filters.gaussian(image[_dapi_index],sigma=2) #smoothen the image using a gaussian filter
# ---> 30     nuc_mask = seg.segment_nuclei_cellpose([processed_nuc])[0] #obtain nuc labelled image
#      31
#      32     #save image
#
# ~/insitro/trainbow/trainbow/segmentation/cell_segmentation.py in segment_nuclei_cellpose()
#      29     model = models.Cellpose(gpu = use_gpu, model_type='nuclei')
#      30
# ---> 31     nuc_masks, _, _, _ = model.eval(images,
#      32                                     diameter = nuc_dia,
#      33                                     channels = [0,0],
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py in eval()
#     255         tic = time.time()
#     256         models_logger.info('~~~ FINDING MASKS ~~~')
# --> 257         masks, flows, styles = self.cp.eval(x,
#     258                                             batch_size=batch_size,
#     259                                             invert=invert,
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py in eval()
#     469             iterator = trange(nimg, file=tqdm_out) if nimg>1 else range(nimg)
#     470             for i in iterator:
# --> 471                 maski, stylei, flowi = self.eval(x[i],
#     472                                                  batch_size=batch_size,
#     473                                                  channels=channels[i] if (len(channels)==len(x) and
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py in eval()
#     513                     self.net.collect_params().grad_req = 'null'
#     514
# --> 515             masks, styles, dP, cellprob, p = self._run_cp(x,
#     516                                                           compute_masks=compute_masks,
#     517                                                           normalize=normalize,
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/models.py in _run_cp()
#     570                     img = transforms.resize_image(img, rsz=rescale)
#     571
# --> 572                 yf, style = self._run_nets(img, net_avg=net_avg,
#     573                                         augment=augment, tile=tile,
#     574                                         tile_overlap=tile_overlap)
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py in _run_nets()
#     395                 if not self.torch:
#     396                     self.net.collect_params().grad_req = 'null'
# --> 397                 y0, style = self._run_net(img, augment=augment, tile=tile,
#     398                                           tile_overlap=tile_overlap, bsize=bsize,
#     399                                           return_conv=return_conv)
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py in _run_net()
#     467         # run network
#     468         if tile or augment or imgs.ndim==4:
# --> 469             y, style = self._run_tiled(imgs, augment=augment, bsize=bsize,
#     470                                       tile_overlap=tile_overlap,
#     471                                       return_conv=return_conv)
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py in _run_tiled()
#     570             for k in range(niter):
#     571                 irange = np.arange(batch_size*k, min(IMG.shape[0], batch_size*k+batch_size))
# --> 572                 y0, style = self.network(IMG[irange], return_conv=return_conv)
#     573                 y[irange] = y0.reshape(len(irange), y0.shape[-3], y0.shape[-2], y0.shape[-1])
#     574                 if k==0:
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/core.py in network()
#     339             if self.mkldnn:
#     340                 self.net = mkldnn_utils.to_mkldnn(self.net)
# --> 341         y, style = self.net(X)
#     342         if self.mkldnn:
#     343             self.net.to(torch_CPU)
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl()
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py in forward()
#     197         if not self.style_on:
#     198             style = style * 0
# --> 199         T0 = self.upsample(style, T0, self.mkldnn)
#     200         T0    = self.output(T0)
#     201         if self.mkldnn:
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl()
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py in forward()
#     164             else:
#     165                 x = self.upsampling(x)
# --> 166             x = self.up[n](x, xd[n], style, mkldnn=mkldnn)
#     167         return x
#     168
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl()
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/cellpose/resnet_torch.py in forward()
#     115
#     116     def forward(self, x, y, style, mkldnn=False):
# --> 117         x = self.proj(x) + self.conv[1](style, self.conv[0](x) + y, mkldnn=mkldnn)
#     118         x = x + self.conv[3](style, self.conv[2](style, x, mkldnn=mkldnn), mkldnn=mkldnn)
#     119         return x
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl()
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/container.py in forward()
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl()
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
#   File "/home/ec2-user/miniconda3/envs/insitro/lib/python3.9/site-packages/torch/utils/mkldnn.py", line 171, in forward
#     @torch.jit.script_method
#     def forward(self, x):
#         return torch.batch_norm(
#                ~~~~~~~~~~~~~~~~ <--- HERE
#             x,
#             self.weight,
# RuntimeError: [enforce fail at CPUAllocator.cpp:68] . DefaultCPUAllocator: can't allocate memory: you tried to allocate 102760448 bytes. Error code 12 (Cannot allocate memory)

# %%
plate_id = 'PB2455' #plate id
microscope_id = 6 # techdev scope or nikon 4
#Fluroscent map
channel_map ={
    'DAPI':1,
    'eGFP':2,
    'mOrange':0,
    'mKate2':3,
    'DPC_top':4,
    'DPC_bottom':5,
    'DPC_left':6,
    'DPC_right':7
}

well_map = {
            "CD118_0ng" : ['A01'],
            "CD118_250ng" : ['A02'],
            "CD118_500ng" : ['A03'],
            "CD118_1000ng" : ['A04'],
            
            "CM130_0ng" : ['B01'],
            "CM130_250ng" : ['B02'],
            "CM130_500ng" : ['B03'],
            "CM130_1000ng" : ['B04'],
    
            "Cre-TAT" : ['C01'],
            "Mix" : ['C02','C03','C04'],
    
            
}

bucket = 's3://insitro-user/'
output_dir = os.path.join('saradha/',plate_id)

experiment_acquisition_p2 = utils.database_utils.create_acquistion_df(plate_id,microscope_id)
#drop duplicate file paths - keeping only the last row
experiment_acquisition_p2 = experiment_acquisition_p2.drop_duplicates(subset='file_path', keep="last")

## instance segmentation 
subset_df_p2 = experiment_acquisition_p2.groupby('well_loc').apply(lambda x: x.sample(10)).reset_index(drop=True)

nuc_mask_paths = seg.segment_nuclei_batch(acquisition_df = subset_df_p2,
                                          channel_map = channel_map,
                                          num_cpus = 10,
                                          output_dir = os.path.join(bucket,output_dir)
                                          )
cell_mask_paths = seg.segment_cells_from_nuclei_batch(acquisition_df = subset_df_p2,
                                                      channel_map = channel_map,
                                                      num_cpus = 10,
                                                      output_dir = os.path.join(bucket,output_dir))

feat_paths = extract_features_batch(acquisition_df = subset_df_p2,
                                  channel_map = channel_map,
                                  num_cpus = 10,
                                  output_dir = os.path.join(bucket,output_dir))

#save the features df
features = pd.concat([utils.database_utils.load_obj(os.path.join(bucket,path)) 
              for path in utils.database_utils.get_file_list(os.path.join(output_dir,"brainbow_features"))])

utils.database_utils.save_object(features,os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))
cell_features_plate2 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))

image_features = extract_features_batch_FOV(acquisition_df = experiment_acquisition,
                                      channel_map = channel_map,
                                      num_cpus = 10,
                                      output_dir = os.path.join(bucket,output_dir))
utils.database_utils.save_object(image_features,os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))
img_features_plate2 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"image_brainbow_features.pkl"))

# %%
features_plate1 = utils.database_utils.load_obj(os.path.join(os.path.join(bucket,output_dir),"cellular_brainbow_features.pkl"))
