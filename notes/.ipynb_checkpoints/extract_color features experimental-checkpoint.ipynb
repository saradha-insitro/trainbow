# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import trainbow.utils as utils
import trainbow.visualizations.image_viewers as viz
import trainbow.batch.segmenters as seg
import os
import boto3
from skimage import measure
from tqdm import tqdm
# Out:
# 2022-09-02 15:54:08,536 [INFO] WRITING LOG OUTPUT TO /home/ec2-user/.cellpose/run.log

# %%
plate_id = 'PC2089' #plate id
microscope_id = 6 # techdev scope or nikon 4
#Fluroscent map
channel_map ={
    'DAPI':1,
    'eGFP':2,
    'mOrange':0,
    'mKate2':3,
    'DPC_top':4,
    'DPC_bottom':5,
    'DPC_left':6,
    'DPC_right':7
}

well_map = {
            "Control" : ['A01','B01','C01','D01'],
    
            "CA137_0ng" : ['A02'],
            "CA137_250ng" : ['B02'],
            "CA137_500ng" : ['C02'],
            "CA137_1000ng" : ['D02'],
            
            "CM137_0ng" : ['A03'],
            "CM137_250ng" : ['B03'],
            "CM137_500ng" : ['C03'],
            "CM137_1000ng" : ['D03'],
            
            "CD118_0ng" : ['A04'],
            "CD118_250ng" : ['B04'],
            "CD118_500ng" : ['C04'],
            "CD118_1000ng" : ['D04'],

            "CM130_0ng" : ['A05'],
            "CM130_250ng" : ['B05'],
            "CM130_500ng" : ['C05'],
            "CM130_1000ng" : ['D05']
}

bucket = 's3://insitro-user/'
output_dir = os.path.join('saradha/',plate_id)

# %%
experiment_acquisition = utils.database_utils.create_acquistion_df(plate_id,microscope_id)
#drop duplicate file paths - keeping only the last row
experiment_acquisition = experiment_acquisition.drop_duplicates(subset='file_path', keep="last")
experiment_acquisition = experiment_acquisition[experiment_acquisition.measurement_id=='b9aeb061-1d0f-4186-8b39-80e7251c9b60']
# Out:
# For the plate id PC2089, 2 unique measurements were found

# %%
#select a random image 
random_image_uid = 'C04-34'
image = utils.database_utils.read_image(list(experiment_acquisition[experiment_acquisition.uid == random_image_uid].file_path)[0])
nuc_mask = utils.database_utils.read_image(os.path.join(os.path.join(os.path.join(bucket,output_dir),"nuc_seg"),(random_image_uid+'.npy')))
cell_mask = utils.database_utils.read_image(os.path.join(os.path.join(os.path.join(bucket,output_dir),"cell_seg"),(random_image_uid+'.npy')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12518/1317825540.py in <cell line: 6>()
#       4 nuc_mask = utils.database_utils.read_image(os.path.join(os.path.join(os.path.join(bucket,output_dir),"nuc_seg"),(random_image_uid+'.npy')))
#       5 cell_mask = utils.database_utils.read_image(os.path.join(os.path.join(os.path.join(bucket,output_dir),"cell_seg"),(random_image_uid+'.npy')))
# ----> 6 feat = measure_brainbow_features(image,cell_mask,channel_map)
#
# NameError: name 'measure_brainbow_features' is not defined

# %%
## Plot the image
fig = plt.figure(figsize=(6, 2),dpi=300)
fig.subplots_adjust(hspace = 0, wspace= 0)
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)


xlims = (500,1500)
ylims = (500,1500)

ax1.imshow(utils.image_utils.create_cell_image_from_brainbow_FP(image,channel_map),
           vmax=8000,cmap ="gray")
ax1.axis('off')
ax1.set_title('Pseudo cell stain')
ax1.set_xlim(xlims)
ax1.set_ylim(ylims)

ax2.imshow(cell_mask>0,cmap ="gray")
ax2.axis('off')
ax2.set_title('Cell')
ax2.set_xlim(xlims)
ax2.set_ylim(ylims)

ax3.imshow(cell_mask,cmap ="jet")
ax3.axis('off')
ax3.set_title('Cells')
ax3.set_xlim(xlims)
ax3.set_ylim(ylims)
# Out:
# (500.0, 1500.0)

# %%
def _weight_mean_color(graph, src, dst, n):
    """Callback to handle merging nodes by recomputing mean color.

    The method expects that the mean color of `dst` is already computed.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    n : int
        A neighbor of `src` or `dst` or both.

    Returns
    -------
    data : dict
        A dictionary with the `"weight"` attribute set as the absolute
        difference of the mean color between node `dst` and `n`.
    """

    diff = graph.nodes[dst]['mean color'] - graph.nodes[n]['mean color']
    diff = np.linalg.norm(diff)
    return {'weight': diff}


def merge_mean_color(graph, src, dst):
    """Callback called before merging two nodes of a mean color distance graph.

    This method computes the mean color of `dst`.

    Parameters
    ----------
    graph : RAG
        The graph under consideration.
    src, dst : int
        The vertices in `graph` to be merged.
    """
    graph.nodes[dst]['total color'] += graph.nodes[src]['total color']
    graph.nodes[dst]['pixel count'] += graph.nodes[src]['pixel count']
    graph.nodes[dst]['mean color'] = (graph.nodes[dst]['total color'] /
                                      graph.nodes[dst]['pixel count'])


def color_seg_slic_rag(image_path,
                       slic_compactness = 30,
                       slic_n_seg = 1000,
                       rag_thresh = 12,
                       plot_image = False
                      ):
    
    #read in the image
    image = open_as_composite_image(image_path)
    #Increase the image contrast
    corrected_image = exposure.adjust_gamma(image, gamma =1, gain = 10)
    segments = skseg.slic(corrected_image, compactness=slic_compactness, 
                        n_segments=slic_n_seg, start_label=1)

    #generate RAG and segment 
    g = graph.rag_mean_color(corrected_image, segments)
    seg_rag = graph.merge_hierarchical(segments, g, 
                                       thresh=rag_thresh, rag_copy=False,
                                       in_place_merge=True,
                                       merge_func=merge_mean_color,
                                       weight_func=_weight_mean_color)

    number_of_objects  = np.unique(seg_rag)

    #color the labels
    out = color.label2rgb(seg_rag, corrected_image, kind='avg', bg_label=0)
    out = skseg.mark_boundaries(out, seg_rag, (1,1, 1))

    if plot_image:
        fig = plt.figure(figsize=(8, 2),dpi=300)
        fig.subplots_adjust(hspace = 0, wspace= 0)
        ax1 = fig.add_subplot(141)
        ax2 = fig.add_subplot(142)
        ax3 = fig.add_subplot(143)
        ax4 = fig.add_subplot(144)

        ax1.imshow(corrected_image,alpha=0.9)
        ax1.axis('off')
        ax1.set_title('Composite')

        ax2.imshow(skseg.mark_boundaries(corrected_image, segments,color=[1,1,1]))
        ax2.axis('off')
        ax2.set_title('SLIC')

        ax3.imshow(skseg.mark_boundaries(corrected_image, seg_rag,color=[1,1,1]))
        ax3.axis('off')
        ax3.set_title('RAG')

        ax4.imshow(out)
        ax4.axis('off')
        ax4.set_title('RAGSEg')

        fig.show()

# %%
# %reload_ext autoreload
# %autoreload 2

from trainbow.features.intensity_features import brainbow_intensity_features
from trainbow.features.morphology_features import general_morphology

from skimage.color import rgb2hsv

# %%
feat = measure_brainbow_features(image,cell_mask,channel_map)

# %%
def measure_brainbow_features (image: np.ndarray,
                               cell_mask: np.ndarray,
                               channel_map: dict
                                        ):
    """
    This function takes in a raw image and a instance segmentation mask containing segmented objects 
    and a channel map containing the channel index of the brainbow flurophores 
    and then returns a dataframe of the intensity and morphology features. 
        
    
    """
    
    #get hsv image
    rgb_img = utils.image_utils.create_composite_brainbow_image(image,channel_map,True)
    hsv_img = rgb2hsv(rgb_img)
    
    #get the regionprops in the respective channels
    DAPI_props = measure.regionprops(labelled_image, image[channel_map['DAPI']])
    eGFP_props = measure.regionprops(labelled_image, image[channel_map['eGFP']])
    mOrange_props = measure.regionprops(labelled_image, image[channel_map['mOrange']])
    mKate_props = measure.regionprops(labelled_image, image[channel_map['mKate2']])
    hsv_props = measure.regionprops(labelled_image, hsv_img)

    
    features = pd.DataFrame()
    for flag in (range(len(DAPI_props))):
        feat = pd.concat(
                [pd.DataFrame([flag+1], columns=["object_label"]),
                 brainbow_intensity_features(regionmask = DAPI_props[flag].image, 
                                            DAPI_image =  DAPI_props[flag].intensity_image, 
                                            eGFP_image =  eGFP_props[flag].intensity_image, 
                                            mOrange_image =  mOrange_props[flag].intensity_image, 
                                            mKate_image =  mKate_props[flag].intensity_image,
                                            hsv_image = hsv_props[flag].intensity_image).reset_index(drop=True),
                 general_morphology(regionmask = DAPI_props[flag].image).reset_index(drop=True)
                ],

                axis=1)

        features = pd.concat([feat,features], ignore_index = True)
    
    return features

# %%
feat['num_nuclei'] = np.max(nuc_mask)
feat['num_cell'] = np.max(cell_mask)

# %%
os.path.splitext(os.path.basename(cell_masks[image_index]))[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14612/306323801.py in <cell line: 1>()
# ----> 1 os.path.splitext(os.path.basename(cell_masks[image_index]))[0]
#
# NameError: name 'cell_masks' is not defined

# %%
cellular_features = pd.DataFrame()
nuclear_features = pd.DataFrame()

for image_index in tqdm(range(1)):
    uid = os.path.splitext(os.path.basename(cell_masks[image_index]))[0]
    image_path = experiment_acquisition[experiment_acquisition.uid == uid].file_path.unique()[0]

    #read in the raw image
    image = utils.database_utils.read_image(image_path)
    #read in cell mask
    cell_mask = utils.database_utils.read_image(os.path.join('s3://insitro-user/',cell_masks[image_index]))
    #read in nuc mask
    nuc_mask = utils.database_utils.read_image(os.path.join('s3://insitro-user/',nuc_masks[image_index]))

    assert os.path.basename(cell_masks[image_index]) == os.path.basename(nuc_masks[image_index]), "cell mask and nuclear mask do not match"

    #get the regionprops in the respective channels at the cellular levels
    cell_features = measure_brainbow_intensity_features(image, cell_mask, channel_map)
    cell_features['uid'] = uid
    cell_features.rename(columns={'number_objects': 'number_cells', 
                                  'object_label': 'cell_label'}, inplace=True)
    cellular_features = pd.concat([cellular_features,cell_features],  ignore_index = True)

    #get the regionprops in the respective channels at the nuclear levels

    nuc_features = measure_brainbow_intensity_features(image, nuc_mask, channel_map)
    nuc_features['uid'] = uid
    nuc_features.rename(columns={'number_objects': 'number_nuc', 
                                  'object_label': 'nuc_label'}, inplace=True)
    nuclear_features = pd.concat([nuclear_features,cell_features],  ignore_index = True)
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_15683/4209544035.py in <cell line: 4>()
#       3
#       4 for image_index in tqdm(range(1)):
# ----> 5     uid = os.path.splitext(os.path.basename(cell_masks[image_index]))[0]
#       6     image_path = experiment_acquisition[experiment_acquisition.uid == uid].file_path.unique()[0]
#       7
#
# IndexError: list index out of range

# %%
utils.database_utils.save_object(cellular_features, os.path.join(os.path.join('s3://insitro-user/saradha/'plate_id),"nuc_feat.",
                                                        ()))

# %%
path_out = os.path.join(os.path.join('s3://insitro-user/saradha/',plate_id),"nuc_feat.pkl")
path_out
# Out:
# 's3://insitro-user/saradha/PC2089/nuc_feat.pkl'

# %%
from ml_projects.posh.utils import data

# %%
if isinstance(nuclear_features, pd.DataFrame):
    data.save_dataframe(nuclear_features,os.path.join(os.path.join('s3://insitro-user/saradha/',plate_id),"nuc_feat.pkl"))

# %%
data.load_dataframe(os.path.join(os.path.join('s3://insitro-user/saradha/',plate_id),"nuc_feat.pkl"))
# Out:
#         number_cells  cell_label  DAPI_int_min  DAPI_int_d25  DAPI_int_median  \
# 0             1163.0      1162.0         923.0       5209.75          10064.0
# 1             1163.0      1161.0        1797.0       2898.50           6942.5
# 2             1163.0      1160.0        1875.0       3766.00           6407.0
# 3             1163.0      1159.0        2084.0       5339.00          11996.0
# 4             1163.0      1158.0        1798.0       7523.75           9861.0
# ...              ...         ...           ...           ...              ...
# 113717        1306.0         4.0        5368.0      19772.50          25743.0
# 113718        1306.0         3.0        4016.0      10501.00          19657.0
# 113719        1306.0         2.0        4211.0       9798.00          21629.0
# 113720        1306.0         1.0        4164.0       8589.00          23258.0
# 113721        1306.0         0.0        3382.0      14613.25          24902.5
#
# ...
